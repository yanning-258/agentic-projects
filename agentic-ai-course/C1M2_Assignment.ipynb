# %% [markdown]
# ## Graded Lab: Reflection in a Research Agent
#
# In this graded lab, you’ll implement a simple **agentic workflow** designed to simulate reflective thinking in a writing task. This is one building block of a more complex research agent that will be constructed throughout the course.
#
# ### Objective
#
# Build a three-step workflow where an LLM writes an essay draft, critiques it, and rewrites it.
#
# * **Step 1 – Drafting:** Call the LLM to generate an initial draft of an essay based on a simple prompt.
# * **Step 2 – Reflection:** Reflect on the draft using a reasoning step. (Optionally, this can be done with a different model.)
# * **Step 3 – Revision:** Apply the feedback from the reflection to generate a revised version of the essay.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to write your solution code or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the <span style="background-color: red; color: white; padding: 3px 5px; font-size: 16px; border-radius: 5px;">Submit assignment</span> button on the top right of the page.
# ---

# %% [markdown]
# Before interacting with the language models, we initialize the `aisuite` client. This setup loads environment variables (e.g., API keys) from a `.env` file to securely authenticate with backend services. The `ai.Client()` instance will be used to make all model calls throughout this workflow.

# %%
from dotenv import load_dotenv

load_dotenv()

import aisuite as ai

# Define the client. You can use this variable inside your graded functions!
CLIENT = ai.Client()

# %%
import unittests

# %% [markdown]
# ## Exercise 1: `generate_draft` Function
#
# **Objective**:
# Write a function called `generate_draft` that takes in a string topic and uses a language model to generate a complete draft essay.
#
# **Inputs**:
#
# * `topic` (str): The essay topic.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string representing the full draft of the essay.
#
# The setup for calling the LLM using the aisuite library is already provided. Focus on crafting the prompt content. You can reference this setup in later exercises to understand how to interact with the library effectively.

# %%
# GRADED FUNCTION: generate_draft

def generate_draft(topic: str, model: str = "openai:gpt-4o") -> str: 
    
    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""Please write a full essay draft with the following information:
        essay topic: {topic}
        The structure for the essay can be:
        Introduction: A captivating opening, and a key statement of argument or the main message of the essay, depending whether the topic hints argumentative essay or otherwise
        Body Paragraph: If it is an argumentative essay, then 
        Conclusion: summarize essay content
        """

    ### END CODE HERE ###
    
    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %% [markdown]
# Run the following cell to check your code is working correctly:

# %%
# Test your code!
unittests.test_generate_draft(generate_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 2: `reflect_on_draft` Function
#
# **Objective**:
# Write a function called `reflect_on_draft` that takes a previously generated essay draft and uses a language model to provide constructive feedback.
#
# **Inputs**:
#
# * `draft` (str): The essay text to reflect on.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:o4-mini"`.
#
# **Output**:
#
# * A string with feedback in paragraph form.
#
# **Requirements**:
#
# * The feedback should be critical but constructive.
# * It should address issues such as structure, clarity, strength of argument, and writing style.
# * The function should send the draft to the model and return its response.
#
# You do **not** need to rewrite the essay at this step—just analyze and reflect on it.

# %%
# GRADED FUNCTION: reflect_on_draft

def reflect_on_draft(draft: str, model: str = "openai:o4-mini") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    You are a reflection agent, your job is to analyze an essagy draft and criticize where it did not do well and to suggest ways of improvement. 
    You do not need to rewrite the essay, please simply critique and lay our suggestions.
    Essay first draft: {draft}
    Critique the first draft in terms of the following criterias:
    1. structure: Consists of Introduction, Body, Conclusion, where Body can have more than 1 paragraphs
    2. clarity: is the main argument and the sub-arguments connect, and are they clear?
    3. strength of argument: does it strongly support the main argument?
    4. writing style
    The output text you produce should only consist of the feedback on the essay draft, nothing else
    """

    ### END CODE HERE ###

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_reflect_on_draft(reflect_on_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 3: `revise_draft` Function
#
# **Objective**:
# Implement a function called `revise_draft` that improves a given essay draft based on feedback from a reflection step.
#
# **Inputs**:
#
# * `original_draft` (str): The initial version of the essay.
# * `reflection` (str): Constructive feedback or critique on the draft.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string containing the revised and improved essay.
#
# **Requirements**:
#
# * The revised draft should address the issues mentioned in the feedback.
# * It should improve clarity, coherence, argument strength, and overall flow.
# * The function should use the feedback to guide the revision, and return only the final revised essay.
#
# In this final exercise, you'll also need to manage the call to the LLM using the CLIENT, as you've practiced in previous exercises.

# %%
# GRADED FUNCTION: revise_draft

def revise_draft(original_draft: str, reflection: str, model: str = "openai:gpt-4o") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    You are an expert in essay writing, your job here is to rewrite a given draft, addressing the problems highlighted in the feedback.
    The given original draft is here: {original_draft}
    The feedback: {reflection}
    The revised draft should address all the issues mentioned in the feedback
    The revised draft should improve clarity, coherence, argument strength, and overal flow
    The returned string you produce should only consist of the final revised essay only, nothing else should be included.
    """

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    ### END CODE HERE ###

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_revise_draft(revise_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ### 🧪 Test the Reflective Writing Workflow
#
# Use the functions you implemented to simulate the complete writing workflow:
#
# 1. **Generate a draft** in response to the essay prompt.
# 2. **Reflect** on the draft to identify improvements.
# 3. **Revise** the draft using the feedback.
#
# Observe the outputs of each step. You do **not** need to modify the outputs — just verify that the workflow runs as expected and each component returns a valid string.

# %%
essay_prompt = "Should social media platforms be regulated by the government?"

# Agent 1 – Draft
draft = generate_draft(essay_prompt)
print("📝 Draft:\n")
print(draft)

# Agent 2 – Reflection
feedback = reflect_on_draft(draft)
print("\n🧠 Feedback:\n")
print(feedback)

# Agent 3 – Revision
revised = revise_draft(draft, feedback)
print("\n✍️ Revised:\n")
print(revised)
# Out:
# 📝 Draft:
#
# **Title: The Necessity of Government Regulation in Social Media Platforms**
#
# **Introduction**
#
# In the contemporary digital age, social media platforms have become integral to our daily lives, serving as spaces for communication, information sharing, and entertainment. Platforms like Facebook, Twitter, Instagram, and TikTok are not only ubiquitous but also influential, impacting societal norms and individual behaviors. However, with their vast reach and powerful influence comes the challenge of managing the content and activities occurring within these virtual spaces. The question arises: Should social media platforms be regulated by the government? This essay argues that government regulation is necessary to safeguard users, ensure data privacy, and maintain democratic integrity.
#
# **Body Paragraph 1: The Case for User Safety**
#
# One of the primary reasons for government regulation is to enhance user safety on social media platforms. The anonymity provided by these platforms can often lead to harmful behaviors, including cyberbullying, harassment, and the spread of hate speech and misinformation. Despite efforts by companies to self-regulate through community guidelines and automated algorithms, these measures often fall short in effectively identifying and mitigating harmful content. Government regulation can provide a standardized framework ensuring that platforms take proactive and consistent measures to protect users from such online threats. By establishing clear legal standards and penalties for non-compliance, governments can hold social media companies accountable for the safety of their users, much like how other industries are regulated for consumer protection.
#
# **Body Paragraph 2: Ensuring Data Privacy**
#
# Furthermore, government regulation is essential for ensuring data privacy on social media platforms. These platforms house a treasure trove of personal data, often obtained without explicit user consent and exploited for commercial gain. Recent controversies, such as the Cambridge Analytica scandal, have demonstrated the extent of data privacy violations and their potential to manipulate public opinion. Current self-regulatory practices are insufficient, as profit motives often override user privacy concerns. Government intervention can set clear rules and limitations on data collection practices, ensuring that users' personal information is protected against undue exploitation. By instituting rigorous checks and enforcing transparency, governments can help restore user trust in social media platforms.
#
# **Body Paragraph 3: Preserving Democratic Integrity**
#
# Another compelling argument for government regulation is the need to preserve democratic integrity. Social media platforms can be misused to disseminate false information, polarize societies, and influence election outcomes. The unregulated spread of fake news and propaganda poses a serious threat to the democratic process, undermining informed decision-making and fostering division. Governments have a responsibility to ensure that the digital public square does not become a breeding ground for misinformation. By implementing regulations that promote accurate information dissemination and penalize platforms that fail to curb misinformation, governments can protect democratic values and ensure that social media remains a conduit for constructive dialogue.
#
# **Conclusion**
#
# In conclusion, the regulation of social media platforms by the government is essential to address the multifaceted challenges posed by these influential entities. By enhancing user safety, ensuring data privacy, and preserving democratic integrity, government regulation can provide a framework that balances the benefits of social media with necessary safeguards. As these platforms continue to evolve and shape the fabric of society, it is imperative that regulatory measures keep pace to protect the rights and well-being of all users. Ultimately, a collaborative effort between governments, social media companies, and users will be required to create a digital environment that fosters innovation, trust, and accountability.
#
# 🧠 Feedback:
#
# Structure:
# - The essay follows a conventional format with a clear introduction, three body paragraphs, and a conclusion.
# - Transitions between sections are present but could be smoother; consider adding brief signposts at the end of each paragraph to preview the next point.
# - There is no engagement with counterarguments or alternative viewpoints; including a paragraph addressing potential objections would strengthen the overall structure.
#
# Clarity:
# - The thesis (“government regulation is necessary to safeguard users, ensure data privacy, and maintain democratic integrity”) is clearly stated in the introduction and echoed in each body paragraph.
# - Sub-arguments align with the thesis, but some topic sentences are formulaic; revise them to more precisely reflect each paragraph’s focus.
# - Certain terms (e.g., “democratic integrity,” “user safety”) would benefit from concise definitions early on to avoid ambiguity.
#
# Strength of Argument:
# - The examples (cyberbullying, Cambridge Analytica) illustrate key points but remain largely anecdotal; incorporate current statistics, case studies, or expert testimony to bolster credibility.
# - The argument would gain nuance by acknowledging counterpoints such as free-speech concerns or risks of governmental overreach—and then rebutting them.
# - Offering concrete regulatory models or referencing existing legislation (e.g., GDPR) would move beyond broad assertions and demonstrate feasibility.
#
# Writing Style:
# - The tone is appropriately formal, but several sentences are lengthy and could be tightened to improve readability.
# - Repetition of certain phrases (“platform regulation,” “user safety”) lessens impact; vary word choice and use pronouns or synonyms where clarity permits.
# - Use active voice more consistently (“Governments must enforce…” rather than “Government regulation can provide…”).
# - Eliminate filler phrases (“it is imperative that,” “in conclusion”) or replace them with more direct transitions.
#
# ✍️ Revised:
#
# **Title: The Necessity of Government Regulation in Social Media Platforms**
#
# **Introduction**
#
# In today's digital era, social media platforms are pivotal to our everyday activities, revolutionizing communication, information sharing, and entertainment. Ubiquitous platforms like Facebook, Twitter, Instagram, and TikTok wield substantial influence, shaping societal norms and personal habits. This power brings the challenge of effectively managing content and interactions in these digital spaces. A pressing issue thereby emerges: Should governments regulate social media platforms? This essay contends that governmental oversight is vital to protect users, safeguard data privacy, and uphold democratic processes.
#
# **Body Paragraph 1: Enhancing User Safety**
#
# Regulating social media is essential for ensuring user safety. Anonymity on these platforms can foster harmful behaviors, such as cyberbullying and the proliferation of hate speech. Although companies attempt self-regulation with community guidelines and algorithms, these methods often fail to adequately identify and control harmful content. Government intervention can establish consistent, standard protocols to ensure proactive measures for user protection. By imposing clear legal frameworks and penalties for non-compliance, akin to regulations in other consumer industries, governments can hold social media companies accountable. This consistency is crucial as we address broader issues of online safety.
#
# **Body Paragraph 2: Safeguarding Data Privacy**
#
# Furthermore, government regulation is key in protecting data privacy on social media. These platforms store vast amounts of personal data, often collected without explicit consent and exploited for profit. Incidents like the Cambridge Analytica scandal highlight serious data privacy breaches and their potential to sway public opinion. Current self-regulatory efforts fall short as profit motives often eclipse user privacy. Government regulations can define strict rules on data collection, ensuring users' personal information remains secure. Implementing stringent checks and promoting transparency can also help rebuild user trust in these platforms.
#
# **Body Paragraph 3: Preserving Democratic Processes**
#
# Equally important is the regulation of social media to maintain democratic processes. These platforms are susceptible to misuse for spreading misinformation, intensifying societal divides, and influencing elections. Unchecked dissemination of fake news threatens informed decision-making and democratic unity. It is the government's duty to ensure that digital forums do not devolve into breeding grounds for falsehoods. Introducing regulations that endorse accurate information and penalize negligence in controlling misinformation can protect democratic values. Regulation ensures social media remains a space for constructive discourse.
#
# **Addressing Counterarguments**
#
# While the necessity of regulation is evident, concerns about free speech and government overreach cannot be ignored. Critics argue that strict regulation might stifle open dialogue and innovation. However, properly designed legislation, akin to Europe's GDPR, can offer comprehensive protection without infringing on free speech. By incorporating balanced regulatory frameworks, governments can protect user rights while preserving free expression.
#
# **Conclusion**
#
# In summary, government oversight of social media is critical for tackling the complex challenges posed by these platforms. By enhancing user safety, protecting data privacy, and preserving democratic integrity, regulation creates a balanced framework that optimizes social media's benefits while instituting necessary safeguards. As platforms evolve, regulatory measures must progress similarly to secure the rights and security of all users. A collaborative approach involving governments, social media entities, and individuals is vital to forging a digital landscape that supports innovation, trust, and accountability.

# %% [markdown]
# To better visualize the output of each step in the reflective writing workflow, we use a utility function called `show_output`. This function displays the results of each stage (drafting, reflection, and revision) in styled boxes with custom background and text colors, making it easier to compare and understand the progression of the essay.

# %%
from utils import show_output

essay_prompt = "Should social media platforms be regulated by the government?"

show_output("Step 1 – Draft", draft, background="#fff8dc", text_color="#333333")
show_output("Step 2 – Reflection", feedback, background="#e0f7fa", text_color="#222222")
show_output("Step 3 – Revision", revised, background="#f3e5f5", text_color="#222222")
# Out:
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #fff8dc;
#         color: #333333;
#     ">
#         <h3 style="margin-top: 0;">Step 1 – Draft</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">**Title: The Necessity of Government Regulation in Social Media Platforms**
#
# **Introduction**
#
# In the contemporary digital age, social media platforms have become integral to our daily lives, serving as spaces for communication, information sharing, and entertainment. Platforms like Facebook, Twitter, Instagram, and TikTok are not only ubiquitous but also influential, impacting societal norms and individual behaviors. However, with their vast reach and powerful influence comes the challenge of managing the content and activities occurring within these virtual spaces. The question arises: Should social media platforms be regulated by the government? This essay argues that government regulation is necessary to safeguard users, ensure data privacy, and maintain democratic integrity.
#
# **Body Paragraph 1: The Case for User Safety**
#
# One of the primary reasons for government regulation is to enhance user safety on social media platforms. The anonymity provided by these platforms can often lead to harmful behaviors, including cyberbullying, harassment, and the spread of hate speech and misinformation. Despite efforts by companies to self-regulate through community guidelines and automated algorithms, these measures often fall short in effectively identifying and mitigating harmful content. Government regulation can provide a standardized framework ensuring that platforms take proactive and consistent measures to protect users from such online threats. By establishing clear legal standards and penalties for non-compliance, governments can hold social media companies accountable for the safety of their users, much like how other industries are regulated for consumer protection.
#
# **Body Paragraph 2: Ensuring Data Privacy**
#
# Furthermore, government regulation is essential for ensuring data privacy on social media platforms. These platforms house a treasure trove of personal data, often obtained without explicit user consent and exploited for commercial gain. Recent controversies, such as the Cambridge Analytica scandal, have demonstrated the extent of data privacy violations and their potential to manipulate public opinion. Current self-regulatory practices are insufficient, as profit motives often override user privacy concerns. Government intervention can set clear rules and limitations on data collection practices, ensuring that users' personal information is protected against undue exploitation. By instituting rigorous checks and enforcing transparency, governments can help restore user trust in social media platforms.
#
# **Body Paragraph 3: Preserving Democratic Integrity**
#
# Another compelling argument for government regulation is the need to preserve democratic integrity. Social media platforms can be misused to disseminate false information, polarize societies, and influence election outcomes. The unregulated spread of fake news and propaganda poses a serious threat to the democratic process, undermining informed decision-making and fostering division. Governments have a responsibility to ensure that the digital public square does not become a breeding ground for misinformation. By implementing regulations that promote accurate information dissemination and penalize platforms that fail to curb misinformation, governments can protect democratic values and ensure that social media remains a conduit for constructive dialogue.
#
# **Conclusion**
#
# In conclusion, the regulation of social media platforms by the government is essential to address the multifaceted challenges posed by these influential entities. By enhancing user safety, ensuring data privacy, and preserving democratic integrity, government regulation can provide a framework that balances the benefits of social media with necessary safeguards. As these platforms continue to evolve and shape the fabric of society, it is imperative that regulatory measures keep pace to protect the rights and well-being of all users. Ultimately, a collaborative effort between governments, social media companies, and users will be required to create a digital environment that fosters innovation, trust, and accountability.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #e0f7fa;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 2 – Reflection</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Structure:
# - The essay follows a conventional format with a clear introduction, three body paragraphs, and a conclusion.
# - Transitions between sections are present but could be smoother; consider adding brief signposts at the end of each paragraph to preview the next point.
# - There is no engagement with counterarguments or alternative viewpoints; including a paragraph addressing potential objections would strengthen the overall structure.
#
# Clarity:
# - The thesis (“government regulation is necessary to safeguard users, ensure data privacy, and maintain democratic integrity”) is clearly stated in the introduction and echoed in each body paragraph.
# - Sub-arguments align with the thesis, but some topic sentences are formulaic; revise them to more precisely reflect each paragraph’s focus.
# - Certain terms (e.g., “democratic integrity,” “user safety”) would benefit from concise definitions early on to avoid ambiguity.
#
# Strength of Argument:
# - The examples (cyberbullying, Cambridge Analytica) illustrate key points but remain largely anecdotal; incorporate current statistics, case studies, or expert testimony to bolster credibility.
# - The argument would gain nuance by acknowledging counterpoints such as free-speech concerns or risks of governmental overreach—and then rebutting them.
# - Offering concrete regulatory models or referencing existing legislation (e.g., GDPR) would move beyond broad assertions and demonstrate feasibility.
#
# Writing Style:
# - The tone is appropriately formal, but several sentences are lengthy and could be tightened to improve readability.
# - Repetition of certain phrases (“platform regulation,” “user safety”) lessens impact; vary word choice and use pronouns or synonyms where clarity permits.
# - Use active voice more consistently (“Governments must enforce…” rather than “Government regulation can provide…”).
# - Eliminate filler phrases (“it is imperative that,” “in conclusion”) or replace them with more direct transitions.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #f3e5f5;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 3 – Revision</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">**Title: The Necessity of Government Regulation in Social Media Platforms**
#
# **Introduction**
#
# In today's digital era, social media platforms are pivotal to our everyday activities, revolutionizing communication, information sharing, and entertainment. Ubiquitous platforms like Facebook, Twitter, Instagram, and TikTok wield substantial influence, shaping societal norms and personal habits. This power brings the challenge of effectively managing content and interactions in these digital spaces. A pressing issue thereby emerges: Should governments regulate social media platforms? This essay contends that governmental oversight is vital to protect users, safeguard data privacy, and uphold democratic processes.
#
# **Body Paragraph 1: Enhancing User Safety**
#
# Regulating social media is essential for ensuring user safety. Anonymity on these platforms can foster harmful behaviors, such as cyberbullying and the proliferation of hate speech. Although companies attempt self-regulation with community guidelines and algorithms, these methods often fail to adequately identify and control harmful content. Government intervention can establish consistent, standard protocols to ensure proactive measures for user protection. By imposing clear legal frameworks and penalties for non-compliance, akin to regulations in other consumer industries, governments can hold social media companies accountable. This consistency is crucial as we address broader issues of online safety.
#
# **Body Paragraph 2: Safeguarding Data Privacy**
#
# Furthermore, government regulation is key in protecting data privacy on social media. These platforms store vast amounts of personal data, often collected without explicit consent and exploited for profit. Incidents like the Cambridge Analytica scandal highlight serious data privacy breaches and their potential to sway public opinion. Current self-regulatory efforts fall short as profit motives often eclipse user privacy. Government regulations can define strict rules on data collection, ensuring users' personal information remains secure. Implementing stringent checks and promoting transparency can also help rebuild user trust in these platforms.
#
# **Body Paragraph 3: Preserving Democratic Processes**
#
# Equally important is the regulation of social media to maintain democratic processes. These platforms are susceptible to misuse for spreading misinformation, intensifying societal divides, and influencing elections. Unchecked dissemination of fake news threatens informed decision-making and democratic unity. It is the government's duty to ensure that digital forums do not devolve into breeding grounds for falsehoods. Introducing regulations that endorse accurate information and penalize negligence in controlling misinformation can protect democratic values. Regulation ensures social media remains a space for constructive discourse.
#
# **Addressing Counterarguments**
#
# While the necessity of regulation is evident, concerns about free speech and government overreach cannot be ignored. Critics argue that strict regulation might stifle open dialogue and innovation. However, properly designed legislation, akin to Europe's GDPR, can offer comprehensive protection without infringing on free speech. By incorporating balanced regulatory frameworks, governments can protect user rights while preserving free expression.
#
# **Conclusion**
#
# In summary, government oversight of social media is critical for tackling the complex challenges posed by these platforms. By enhancing user safety, protecting data privacy, and preserving democratic integrity, regulation creates a balanced framework that optimizes social media's benefits while instituting necessary safeguards. As platforms evolve, regulatory measures must progress similarly to secure the rights and security of all users. A collaborative approach involving governments, social media entities, and individuals is vital to forging a digital landscape that supports innovation, trust, and accountability.</pre>
#     </div>

# %% [markdown]
# ## Check grading feedback
#
# If you have collapsed the right panel to have more screen space for your code, as shown below:
#
# <img src="./images/collapsed.png" alt="Collapsed Image" width="800" height="400"/>
#
# You can click on the left-facing arrow button (highlighted in red) to view feedback for your submission after submitting it for grading. Once expanded, it should display like this:
#
# <img src="./images/expanded.png" alt="Expanded Image" width="800" height="400"/>
